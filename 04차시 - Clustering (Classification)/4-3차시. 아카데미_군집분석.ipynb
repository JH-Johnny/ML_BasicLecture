# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn import cluster

academy = pd.read_csv('academy.csv')
academy.columns = ['num' , 'kor' , 'math' , 'eng' , 'sci' , 'itn']
academy = academy.drop('num', axis=1)
academy.head()
# Out:
#    kor  math  eng  sci  itn
# 0   90    75   85   60   70
# 1   65    90   60   88   80
# 2   45    53   48   50   60
# 3   77    96   62   92   70
# 4   88    89   80   82   90

# %%
# 군집화 하기 위해서 데이터를 array로 바꿈 (index정보나 column 정보는 날라감)
academy_arr = np.array(academy)

# %%
academy.columns , academy_arr , academy_arr.shape
# Out:
# (Index(['kor', 'math', 'eng', 'sci', 'itn'], dtype='object'),
#  array([[ 90,  75,  85,  60,  70],
#         [ 65,  90,  60,  88,  80],
#         [ 45,  53,  48,  50,  60],
#         [ 77,  96,  62,  92,  70],
#         [ 88,  89,  80,  82,  90],
#         [ 90,  92,  90,  96, 100],
#         [ 65,  70,  66,  76,  70],
#         [ 60,  90,  70,  98,  80],
#         [ 46,  56,  43,  55,  60],
#         [ 88,  67,  90,  70,  70],
#         [ 70,  93,  77,  89,  60],
#         [ 99,  80,  95,  70,  80],
#         [ 97,  67,  80,  60,  80],
#         [ 50,  40,  30,  54,  50],
#         [ 90,  77,  92,  60,  70],
#         [ 55,  88,  67,  92,  60],
#         [ 77,  90,  70,  98,  70],
#         [ 90,  89,  80,  92,  90],
#         [ 76,  90,  80,  92,  70],
#         [ 70,  92,  80,  95,  70],
#         [ 76,  75,  70,  82,  80],
#         [ 77,  92,  68,  89,  80],
#         [ 60,  50,  70,  40,  60],
#         [ 54,  70,  56,  72,  60],
#         [ 72,  88,  67,  95,  80],
#         [ 58,  76,  59,  80,  70],
#         [ 88,  60,  76,  58,  60],
#         [ 84,  88,  90,  92,  90],
#         [ 45,  76,  56,  78,  70],
#         [ 76,  54,  70,  58,  70],
#         [ 66,  90,  70,  88,  70],
#         [ 88,  80,  85,  88,  90],
#         [ 71,  48,  69,  50,  80],
#         [ 90,  77,  82,  65,  80],
#         [ 34,  32,  45,  50,  50],
#         [ 56,  78,  67,  89,  60],
#         [ 70,  95,  72,  80,  70],
#         [ 93,  90,  89,  91,  90],
#         [ 92,  97,  90,  89,  80],
#         [ 56,  63,  70,  71,  70],
#         [ 88,  57,  78,  60,  80],
#         [ 90,  92,  88,  94,  90],
#         [ 91,  67,  89,  70,  60],
#         [ 58,  77,  62,  88,  70],
#         [ 54,  50,  45,  33,  60],
#         [ 78,  91,  77,  90,  80],
#         [ 92,  70,  88,  60,  80],
#         [ 57,  76,  58,  71,  60],
#         [ 97,  90,  96,  90,  90],
#         [ 69,  55,  70,  54,  60],
#         [ 45,  56,  54,  58,  80],
#         [ 65,  90,  70,  92,  70]], dtype=int64),
#  (52, 5))

# %%
model = cluster.KMeans(n_clusters=5)
model.fit(academy_arr)
# Out:
# KMeans(n_clusters=5)

# %%
# labels_ 속성이 기억이 안날 경우 확인해보기
dir(model)
import re
for i in dir(model):
    if re.search("label", i):
        print(i)
# Out:
# labels_

# %%
labels = model.labels_
labels
academy_arr[labels == 0]
# Out:
# array([[90, 75, 85, 60, 70],
#        [88, 67, 90, 70, 70],
#        [97, 67, 80, 60, 80],
#        [90, 77, 92, 60, 70],
#        [88, 60, 76, 58, 60],
#        [76, 54, 70, 58, 70],
#        [71, 48, 69, 50, 80],
#        [90, 77, 82, 65, 80],
#        [88, 57, 78, 60, 80],
#        [91, 67, 89, 70, 60],
#        [92, 70, 88, 60, 80],
#        [69, 55, 70, 54, 60]], dtype=int64)

# %%
# 그래프 그리기
ldata = academy_arr[labels == 0]
plt.scatter(ldata[:, 2], ldata[:, 3],
                  c='red' ,alpha=0.3,s=100 ,marker="o")

ldata = academy_arr[labels == 1]
plt.scatter(ldata[:, 2], ldata[:, 3],
                  c='blue' ,alpha=0.3,s=100 ,marker="o")

ldata = academy_arr[labels == 2]
plt.scatter(ldata[:, 2], ldata[:, 3],
                  c='yellow' ,alpha=0.3,s=100 ,marker="o")

ldata = academy_arr[labels == 3]
plt.scatter(ldata[:, 2], ldata[:, 3],
                  c='black' ,alpha=0.3,s=100 ,marker="o")

ldata = academy_arr[labels == 4]
plt.scatter(ldata[:, 2], ldata[:, 3],
                  c='cyan' ,alpha=0.3,s=100 ,marker="o")

# 축 라벨의 설정
plt.xlabel(academy.columns[2],fontsize='large')
plt.ylabel(academy.columns[3],fontsize='large')

plt.show()

# %%
# Dendrogram (덴드로그램 그려보기)
from scipy.cluster.hierarchy import dendrogram, linkage

Z = linkage(academy_arr , 'ward')

plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('iris')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# 군집이 3개임을 알 수 있다.
# K=3으로 놓고 KMeans를 돌리면 된다.
# 하지만 꼭 K=3이 정답은 아니다. 거리 기준을 좀 더 낮게 잡으면 군집이 4, 5, 6개가 될 수 있다.
